# %%
import pandas as pd
from sklearn.model_selection import train_test_split
import seaborn as sns
import numpy as np
from decimal import Decimal

# %%
df = pd.read_csv('employee_reviews.csv')
df.drop(['Unnamed: 0'], axis=1, inplace=True)
df.shape
# Out:
# (67529, 16)

# %%
train, test = train_test_split(df, test_size=0.2, random_state=42)
train.shape
# Out:
# (54023, 16)

# %%
test.shape
# Out:
# (13506, 16)

# %%
cols = ['overall-ratings', 'work-balance-stars' , 'culture-values-stars', 
                      'carrer-opportunities-stars', 'comp-benefit-stars', 'senior-mangemnet-stars']
def check(input):
    return input.replace('.','',1).isdigit()

ratings = df[cols].astype(str)
ratingsIndex = ratings[ratings.applymap(check)].dropna(axis = 0).index
# df.loc[ratingsIndex, :] we could drop the rows where a rating is missing

# %%
#Need to run this once to fully install nltk
#import nltk
#nltk.download()

# %%
# Python NLP Tutorial: https://pythonspot.com/tokenizing-words-and-sentences-with-nltk/

from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
import string

def tokenize(sentence):
    
    sentence = sentence.translate(str.maketrans('','',string.punctuation)) # Remove special characters
    sentence = sentence.translate({ord(k): None for k in string.digits}) # Remove digits
    
    stopWords = set(stopwords.words('english'))
    ps = PorterStemmer()
    filtered = []
    
    words = word_tokenize(sentence)
    for word in words:
        # Only keep word stems - sort of normalization for NLP
        # word = ps.stem(word)         ** This actually seems problematic **
        print(word + ":" + ps.stem(word))
        # Remove stop words
        if word not in stopWords:
            filtered.append(word)
        else:
            print(word)
    return filtered
        
tokenize(df.loc[1,'pros'])
#df['pros'].apply(tokenize) #tokenize the pros column
# Out:
# Food:food
# food:food
# food:food
# cafes:cafe
# on:on
# on
# main:main
# campus:campu
# MTV:mtv
# alone:alon
# Minikitchens:minikitchen
# snacks:snack
# drinks:drink
# free:free
# breakfastlunchdinner:breakfastlunchdinn
# all:all
# all
# day:day
# errrday:errrday
# Benefitsperks:benefitsperk
# Free:free
# gym:gym
# access:access
# on:on
# on
# MTV:mtv
# campus:campu
# Free:free
# self:self
# service:servic
# laundry:laundri
# washerdryer:washerdry
# available:avail
# Bowling:bowl
# alley:alley
# Volley:volley
# ball:ball
# pit:pit
# Custombuilt:custombuilt
# and:and
# and
# exclusive:exclus
# employee:employe
# use:use
# only:onli
# only
# outdoor:outdoor
# sport:sport
# park:park
# MTV:mtv
# Free:free
# healthfitness:healthfit
# assessments:assess
# Dogfriendly:dogfriendli
# Etc:etc
# etc:etc
# etc:etc
# Compensation:compens
# In:In
# or:or
# or
# Google:googl
# updated:updat
# its:it
# its
# compensation:compens
# packages:packag
# so:so
# so
# that:that
# that
# they:they
# they
# were:were
# were
# more:more
# more
# competitive:competit
# For:for
# the:the
# the
# size:size
# of:of
# of
# the:the
# the
# organization:organ
# K:K
# it:it
# it
# has:ha
# has
# remained:remain
# relatively:rel
# innovative:innov
# nimble:nimbl
# and:and
# and
# fastpaced:fastpac
# and:and
# and
# open:open
# with:with
# with
# communication:commun
# but:but
# but
# that:that
# that
# is:is
# is
# definitely:definit
# changing:chang
# for:for
# for
# the:the
# the
# worse:wors
# With:with
# so:so
# so
# many:mani
# departments:depart
# focus:focu
# areas:area
# and:and
# and
# products:product
# in:in
# in
# theory:theori
# you:you
# you
# should:should
# should
# have:have
# have
# plenty:plenti
# of:of
# of
# opportunity:opportun
# to:to
# to
# grow:grow
# your:your
# your
# career:career
# horizontally:horizont
# or:or
# or
# vertically:vertic
# In:In
# practice:practic
# not:not
# not
# true:true
# You:you
# get:get
# to:to
# to
# work:work
# with:with
# with
# some:some
# some
# of:of
# of
# the:the
# the
# brightest:brightest
# most:most
# most
# innovative:innov
# and:and
# and
# hardworkingdiligent:hardworkingdilig
# minds:mind
# in:in
# in
# the:the
# the
# industry:industri
# Theres:there
# a:a
# a
# con:con
# to:to
# to
# that:that
# that
# too:too
# too
# see:see
# below:below
# below
# ['Food',
#  'food',
#  'food',
#  'cafes',
#  'main',
#  'campus',
#  'MTV',
#  'alone',
#  'Minikitchens',
#  'snacks',
#  'drinks',
#  'free',
#  'breakfastlunchdinner',
#  'day',
#  'errrday',
#  'Benefitsperks',
#  'Free',
#  'gym',
#  'access',
#  'MTV',
#  'campus',
#  'Free',
#  'self',
#  'service',
#  'laundry',
#  'washerdryer',
#  'available',
#  'Bowling',
#  'alley',
#  'Volley',
#  'ball',
#  'pit',
#  'Custombuilt',
#  'exclusive',
#  'employee',
#  'use',
#  'outdoor',
#  'sport',
#  'park',
#  'MTV',
#  'Free',
#  'healthfitness',
#  'assessments',
#  'Dogfriendly',
#  'Etc',
#  'etc',
#  'etc',
#  'Compensation',
#  'In',
#  'Google',
#  'updated',
#  'compensation',
#  'packages',
#  'competitive',
#  'For',
#  'size',
#  'organization',
#  'K',
#  'remained',
#  'relatively',
#  'innovative',
#  'nimble',
#  'fastpaced',
#  'open',
#  'communication',
#  'definitely',
#  'changing',
#  'worse',
#  'With',
#  'many',
#  'departments',
#  'focus',
#  'areas',
#  'products',
#  'theory',
#  'plenty',
#  'opportunity',
#  'grow',
#  'career',
#  'horizontally',
#  'vertically',
#  'In',
#  'practice',
#  'true',
#  'You',
#  'get',
#  'work',
#  'brightest',
#  'innovative',
#  'hardworkingdiligent',
#  'minds',
#  'industry',
#  'Theres',
#  'con',
#  'see']
